# %% [markdown]
# # Jupyter Notebook
#
# Welcome to the first lesson in the Python Series. This is not going to be focused on Python in a very technical way but more so on Jupyter Notebook - a fantasic Interactive Tool for rapidly developing code.
#
# Jupyter Notebook is notable (ha.) popular amongst Data Scientists (from junior to senior) for its ease of representing information and data in a way which can be ingested by both Technical and Non-Technical Individuals.
#
# This is also the reason why I have chosen Jupyter Notebook to teach some Python Fundamentals.
#
# ## OK - so what is Jupyter Notebook?
#
# Before we jump into the answer of that question - a couple of high level concepts first!
#
# ### Kernel
#
# A Kernel is a self contained instance of Python. That is to say - whenever you run *any* Python code - a Kernel is created for the code to run within - and once done - terminates and closes itself (unless otherwise instructed to)
#
# Think of a Kernel as a table at a fancy restaurant that only takes 1 sitting a night. The code can be though of as the guests and when they come in - they eat their food (run their code) and when they're done - they leave and the restaurant cleans up and closes - until the next set of guests come along. For the guests themselves - the restaurant (the kernel) makes sure that *nothing* from the previous guests is available to the current or the next guests and vice versa - self contained!
#
# ### Interactive Development Environment (IDE)
#
# An Interactive Development Environment or IDE is something which code developers (like yourself now!) use to develop code. They usually contain handy dandy features to make coding easier (like autocompletion, formatting, amongst others). As mentioned previously - Jupyter Notebook was popularized (don't quote me on it) by Data Scientists as it let them write code as well as provide presentable notes (like this) to audiences - allowing them to easily show results and presentations around the notes side by side.
#
# ## So I know what an IDE and a Kernel is... so what is Jupyter Notebook
#
# Jupyter Notebook is effectively a wrapper around a *persistent* Python Kernel. That is to say - when we run code in Jupyter Notebook - whatever we had run - doesn't go away - it stays available in the Kernel as the Kernel has received specific instruction to not terminate after code has been run. This might seem trivial - but in practise - this makes it *extremely* powerful as a tool as it allows me as a code devloper to insert myself at specific points and view what exactly is going on so that I can better understand what it is that I am writing as well as troubleshoot effectively if I have written bad code.
#
# <!-- THE BELOW CODE IS BEYOND USELESS AND/OR I AM STUPID AF -->
# <!-- ![PLEASE RENDER OH GOD](https://github.com/leeTimothy/practicalCS_101/blob/main/source/2021/Python/JupyterNB/python.png?raw=true) -->

# %%
### Pure Python Code and Jupyter
from IPython.display import Image, display
display(Image(filename='source/2021/Python/1.JupyterNB/python.png', embed=True))

# %% [markdown]
# # So how do we use it?
#
# There are plenty of guides of how to use Jupyter Notebook on Youtube so I won't parrot them.
#
# For this exercise - we'll run through the following:
# - Opening up a New Code Box (for running code)
# - Opening up a New Markdown Box (for adding comments)
# - Restarting the Kernel
# - Clearing all outputs
#
# The majority if not all of these commands are held in the top bar of your Jupyter Notebook.
#
# ## Warning!
#
# If you're looking at the top of your Jupyter Notebook right now and thinking - Tim's crazy - there isn't any of this stuff here - it's probably because you're still viewing this in Github! If you haven't already - clone the Repository to your computer and start up your Python Environment. If this all sounded like gobble-de-gook to you - reach out to Tim.
#
# ## New Code Cells
#
# This can be achieved with the "+ Code" Button. This is good for really quickly testing out lines of code to make sure they don't bug out before putting them into your main piece of code. We'll try with a basic example below.

# %%
# As is coding tradition - the first thing we print out most often is "Hello World". Tim's had a fair too many beers and as such - I can't read anything 5 cm in front of my face right now and need a hand.
# Change whatever the hell it is that Tim typed out below to make sure it prints Hello World properly. When you're ready - hit Ctrl-Enter on Windows or Command-Enter on Mac to run the cell

print('Note to self - Drink less on weeknights')

# %% [markdown]
# You'll notice in the above that the output is already saved and that Tim has already put through the incorrect code. Once you've fixed that up - Create a new code box below this Cell and print out for me: "I know now how to use Code Blocks!". Don't forget to run it as well with Ctrl-Enter on Windows or Command-Enter on Mac.

# %% [markdown]
# ## New Markdown Cells
#
# After we've mastered the New Code Cell - let's move onto the Markdown Cells. Markdown cells are used primarily to put Stylized Cells in between your code in order to make it legible and to explain what you're trying to do. Note that running these cells formats them only and does not actually execute any of the python code within.
#
# For Example - the following does not run:
#
# print('Hello World')
#
# Similarly - the above isn't "linted" or stylized to show you what's going on.

# %% [markdown]
# ## Restarting the Kernel
#
# This is where it'll get interesting. Remember - in a Pure Python Application - Once the code has finished executing and completed its list of instructions - the Kernel will terminate and you won't be able to refer back to any of the objects created in that session without recreating them.
#
# For instance - let's create an object 'x' and object 'y'

# %%
x = 5
y = 10

# %% [markdown]
# You'll notice the above has just created the references of "x" being equal to 5 and y being equal to "10".
#
# If this was the contents of a .py file and the file was run, you would get nothing as an output as other than assigning values to x and y - nothing else has been asked of the file and it would close down.
#
# But if you run the contents of the below file - since we're still running in the same kernel - you'll get an output!

# %%
x + y

# %% [markdown]
# To Demonstrate this capability end to end - do the following:
# - Assign Values to x and y by running the cell above last
# - Restart the Kernel
# - Run the above cell - it *should* error out

# %% [markdown]
# ## Clearing all Output
#
# This is for when you need to make sure everything is running fine end to end. Clearing all output again should be in the top bar and you should see that the contents of Code Cells disappears after running this. Think of it as a clean slate for the outputs.
#
# It is important to note that this just clears the outputs of the cells, this does NOT clear out the state of objects inside the python kernel, i.e. if you have assigned a value to x - it will still be that same value even after you've cleaned out the Outputs of all cells.

# %% [markdown]
# # Closing Statements
#
# This is just a brief (hopefully) overview of what Jupyter Notebook is capable of. It will be used as the basis of the lessons moving forward as it allows for me to explain what's happening in an easy enough manner as well as for you the reader to run the code.
#
# Next week we'll begin to go through Python Data Types as well as some basic operations. See you then!
